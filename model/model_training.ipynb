# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Processing Label Studio Exports for Spacy
# This notebook processes exports from Label Studio for use in Spacy.

# %%
import os
from pprint import pprint
from pathlib import Path

from processor import Processor

# Set the root directory of the project
ROOT_DIR = os.path.abspath(
    os.path.join(os.path.dirname("model_trainig.ipynb"), os.pardir)
)  # This file is the root of the project
DATA_PATH = os.path.join(ROOT_DIR, "data")

# Determine which assignment component to run
COMPONENT: int = 1 # 1 or 2

# Define all general paths
NER_MODEL: Path = os.path.join(ROOT_DIR, 'model', 'ner_model')
REL_MODEL: Path = os.path.join(ROOT_DIR, 'model', 'rel_model')

processor = Processor(ROOT_DIR)

# %%
# Define all component specific paths
if COMPONENT == 1:
    ANNOTATIONS: Path = 'final_assignment_1.json'
    GROUND_TRUTHS: Path = 'label_studio_ground_truth_task1.json'
    NER_DEV: Path = os.path.join(NER_MODEL, "assets", "dev_1.json")
    NER_TRAIN: Path = os.path.join(NER_MODEL, "assets", "train_1.json")
    NER_DEV_CORP: Path = os.path.join(NER_MODEL, "corpus", "dev_1.spacy")
    NER_TRAIN_CORP: Path = os.path.join(NER_MODEL, "corpus", "train_1.spacy")
    NER_OUTPUT: Path = os.path.join(NER_MODEL, "training_1")
    REL_ASSETS_TRAIN: Path = os.path.join(REL_MODEL, "assets", "annotations_1_train.jsonl")
    REL_ASSETS_DEV: Path = os.path.join(REL_MODEL, "assets", "annotations_1_dev.jsonl")
    REL_OUTPUT: Path = os.path.join(REL_MODEL, "training_1")
elif COMPONENT == 2:
    ANNOTATIONS: Path = ''
    GROUND_TRUTHS: Path = ''
    NER_DEV: Path = os.path.join(NER_MODEL, "assets", "dev_2.json")
    NER_TRAIN: Path = os.path.join(NER_MODEL, "assets", "train_2.json")
    NER_DEV_CORP: Path = os.path.join(NER_MODEL, "corpus", "dev_2.spacy")
    NER_TRAIN_CORP: Path = os.path.join(NER_MODEL, "corpus", "train_2.spacy")
    NER_OUTPUT: Path = os.path.join(NER_MODEL, "training_2")
    REL_ASSETS_TRAIN: Path = os.path.join(REL_MODEL, "assets", "annotations_2_train.jsonl")
    REL_ASSETS_DEV: Path = os.path.join(REL_MODEL, "assets", "annotations_2_dev.jsonl")
    REL_OUTPUT: Path = os.path.join(REL_MODEL, "training_2")
else:
    raise ValueError("COMPONENT must be 1 or 2")

# %% [markdown]
# ## 1. Loading the Data
# ### 1.1. Loading JSON export from Label Studio
# The annotations need to be loaded into the notebook. This is done via the preprocessor Python class. The training_data_export variable will store the item if this item is not used in the ground_truths. Additionally the ground_truth file is read and stored in the ground_truths variable.

# %%
export_data = processor.loadFile(ANNOTATIONS)

# Filter out annotations for which a ground truth exists (drop other annotations for this article as well)
training_data_export = [
    item
    for item in export_data
    if all(annotation["ground_truth"] is False for annotation in item["annotations"])
]
ground_truth_export = processor.loadFile(GROUND_TRUTHS)

# %% [markdown]
# #### 1.1.1 Check the training_data_export
# The exported data constists of all the annotations from a specific text of all the users. The first annotated text in the exported data file looks something like the following:

# %%
print("Length of training data: ", len(training_data_export))
pprint(training_data_export[0])
# Out:
# Length of training data:  102
# {'agreement': 100.0,
#  'annotations': [{'completed_by': {'email': 'n.p.g.t.v.beuningen@student.tue.nl',
#                                    'first_name': '',
#                                    'id': 12634,
#                                    'last_name': ''},
#                   'created_at': '2023-10-12T19:16:05.761058Z',
#                   'draft_created_at': '2023-10-12T19:06:11.353924Z',
#                   'ground_truth': False,
#                   'id': 23190706,
#                   'import_id': None,
#                   'last_action': 'submitted',
#                   'last_created_by': 12634,
#                   'lead_time': 611.387,
#                   'parent_annotation': None,
#                   'parent_prediction': None,
#                   'prediction': {},
#                   'project': 41784,
#                   'result': [{'from_name': 'label',
#                               'id': 'fLVAxBL9tN',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 20,
#                                         'labels': ['landmark_name'],
#                                         'start': 0,
#                                         'text': 'Engelsberg Ironworks'}},
#                              {'from_name': 'label',
#                               'id': 'FvaT_3g4g6',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 39,
#                                         'labels': ['type'],
#                                         'start': 30,
#                                         'text': 'ironworks'}},
#                              {'from_name': 'label',
#                               'id': 'Kw8qk6PrU_',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 53,
#                                         'labels': ['location'],
#                                         'start': 44,
#                                         'text': 'ngelsberg'}},
#                              {'from_name': 'label',
#                               'id': 'Ywe08mn0Fw',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 90,
#                                         'labels': ['location'],
#                                         'start': 69,
#                                         'text': 'Fagersta Municipality'}},
#                              {'from_name': 'label',
#                               'id': 'e3U09m2Wlj',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 104,
#                                         'labels': ['location'],
#                                         'start': 94,
#                                         'text': 'Vstmanland'}},
#                              {'from_name': 'label',
#                               'id': 'kGERm-qOZa',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 112,
#                                         'labels': ['location'],
#                                         'start': 106,
#                                         'text': 'Sweden'}},
#                              {'from_name': 'label',
#                               'id': '4vk4qfOILD',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 126,
#                                         'labels': ['condition'],
#                                         'start': 121,
#                                         'text': 'built'}},
#                              {'from_name': 'label',
#                               'id': 'lWAVqa-wd8',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 134,
#                                         'labels': ['date'],
#                                         'start': 127,
#                                         'text': 'in 1681'}},
#                              {'from_name': 'label',
#                               'id': 'PdfY0Qx4vp',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 158,
#                                         'labels': ['person_name'],
#                                         'start': 138,
#                                         'text': 'Per Larsson Gyllenhk'}},
#                              {'from_name': 'label',
#                               'id': 'YQiC4LiTy8',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 169,
#                                         'labels': ['date'],
#                                         'start': 160,
#                                         'text': '1645-1706'}},
#                              {'from_name': 'label',
#                               'id': 'EtBTqTVm8K',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 220,
#                                         'labels': ['condition'],
#                                         'start': 190,
#                                         'text': "one of the world's most "
#                                                 'modern'}},
#                              {'from_name': 'label',
#                               'id': 'tt1IYZg7rQ',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 230,
#                                         'labels': ['type'],
#                                         'start': 221,
#                                         'text': 'ironworks'}},
#                              {'from_name': 'label',
#                               'id': 'wFBgjgSpBL',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 253,
#                                         'labels': ['date'],
#                                         'start': 245,
#                                         'text': '17001800'}},
#                              {'from_name': 'label',
#                               'id': 'kMyTUIeSGi',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 310,
#                                         'labels': ['date'],
#                                         'start': 300,
#                                         'text': 'since 1993'}},
#                              {'from_name': 'label',
#                               'id': 'PPJUBIdAHY',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 336,
#                                         'labels': ['landmark_name'],
#                                         'start': 316,
#                                         'text': 'Engelsberg Ironworks'}},
#                              {'from_name': 'label',
#                               'id': 'gIK2ocg03g',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 359,
#                                         'labels': ['person_name'],
#                                         'start': 352,
#                                         'text': 'Englika'}},
#                              {'from_name': 'label',
#                               'id': 'FWGfh-zhtf',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 368,
#                                         'labels': ['person_name'],
#                                         'start': 361,
#                                         'text': 'Englika'}},
#                              {'from_name': 'label',
#                               'id': 'U40dx1JyHM',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 393,
#                                         'labels': ['location'],
#                                         'start': 386,
#                                         'text': 'Germany'}},
#                              {'from_name': 'label',
#                               'id': 'KX9FbRpC13',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 415,
#                                         'labels': ['component'],
#                                         'start': 411,
#                                         'text': 'iron'}},
#                              {'from_name': 'label',
#                               'id': 'vWr2p8wZSX',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 429,
#                                         'labels': ['landmark_name'],
#                                         'start': 419,
#                                         'text': 'Engelsberg'}},
#                              {'from_name': 'label',
#                               'id': 'pXv1BdiF8M',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 449,
#                                         'labels': ['date'],
#                                         'start': 430,
#                                         'text': 'in the 14th century'}},
#                              {'from_name': 'label',
#                               'id': 'ltrR1EKtd1',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 538,
#                                         'labels': ['date'],
#                                         'start': 517,
#                                         'text': 'at least 13th century'}},
#                              {'from_name': 'label',
#                               'id': '2o21qqTCQR',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 558,
#                                         'labels': ['people'],
#                                         'start': 544,
#                                         'text': 'local peasants'}},
#                              {'from_name': 'label',
#                               'id': 'f8mBYpHd7V',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 624,
#                                         'labels': ['component'],
#                                         'start': 605,
#                                         'text': ' primitive furnaces'}},
#                              {'from_name': 'label',
#                               'id': 'ERaxvaJNzh',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 577,
#                                         'labels': ['component'],
#                                         'start': 574,
#                                         'text': 'ore'}},
#                              {'from_name': 'label',
#                               'id': 'jpyxibzEvP',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 599,
#                                         'labels': ['component'],
#                                         'start': 595,
#                                         'text': 'iron'}},
#                              {'from_name': 'label',
#                               'id': 'DoWqOcnd_w',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 477,
#                                         'labels': ['component'],
#                                         'start': 473,
#                                         'text': 'iron'}},
#                              {'from_name': 'label',
#                               'id': 'KG9HJ0oduT',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 116,
#                                         'labels': ['landmark_name'],
#                                         'start': 114,
#                                         'text': 'It'}},
#                              {'from_name': 'label',
#                               'id': 'oN-IEemWyu',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 569,
#                                         'labels': ['condition'],
#                                         'start': 564,
#                                         'text': 'mined'}},
#                              {'from_name': 'label',
#                               'id': 'SdL6NpUSz2',
#                               'origin': 'manual',
#                               'to_name': 'text',
#                               'type': 'labels',
#                               'value': {'end': 590,
#                                         'labels': ['condition'],
#                                         'start': 582,
#                                         'text': 'produced'}},
#                              {'direction': 'right',
#                               'from_id': 'fLVAxBL9tN',
#                               'labels': ['org:is_type'],
#                               'to_id': 'FvaT_3g4g6',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'fLVAxBL9tN',
#                               'labels': ['org:located_in'],
#                               'to_id': 'Kw8qk6PrU_',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'fLVAxBL9tN',
#                               'labels': ['org:located_in'],
#                               'to_id': 'Ywe08mn0Fw',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'fLVAxBL9tN',
#                               'labels': ['org:located_in'],
#                               'to_id': 'e3U09m2Wlj',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'fLVAxBL9tN',
#                               'labels': ['org:located_in'],
#                               'to_id': 'kGERm-qOZa',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': '4vk4qfOILD',
#                               'labels': ['org:happened_on'],
#                               'to_id': 'lWAVqa-wd8',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'fLVAxBL9tN',
#                               'labels': ['org:is_type'],
#                               'to_id': 'tt1IYZg7rQ',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'EtBTqTVm8K',
#                               'labels': ['org:happened_on'],
#                               'to_id': 'wFBgjgSpBL',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'KG9HJ0oduT',
#                               'labels': ['org:is_condition'],
#                               'to_id': '4vk4qfOILD',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'KG9HJ0oduT',
#                               'labels': ['org:created_by'],
#                               'to_id': 'PdfY0Qx4vp',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'KG9HJ0oduT',
#                               'labels': ['org:is_condition'],
#                               'to_id': 'EtBTqTVm8K',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'KG9HJ0oduT',
#                               'labels': ['org:is_type'],
#                               'to_id': 'tt1IYZg7rQ',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'KG9HJ0oduT',
#                               'labels': ['org:is_similar_to'],
#                               'to_id': 'fLVAxBL9tN',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'PPJUBIdAHY',
#                               'labels': ['org:is_similar_to'],
#                               'to_id': 'fLVAxBL9tN',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'vWr2p8wZSX',
#                               'labels': ['org:has_component'],
#                               'to_id': 'KX9FbRpC13',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'vWr2p8wZSX',
#                               'labels': ['org:has_component'],
#                               'to_id': 'DoWqOcnd_w',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'vWr2p8wZSX',
#                               'labels': ['org:has_component'],
#                               'to_id': 'ERaxvaJNzh',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'vWr2p8wZSX',
#                               'labels': ['org:has_component'],
#                               'to_id': 'jpyxibzEvP',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'vWr2p8wZSX',
#                               'labels': ['org:has_component'],
#                               'to_id': 'f8mBYpHd7V',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'ERaxvaJNzh',
#                               'labels': ['org:is_condition'],
#                               'to_id': 'oN-IEemWyu',
#                               'type': 'relation'},
#                              {'direction': 'right',
#                               'from_id': 'jpyxibzEvP',
#                               'labels': ['org:is_condition'],
#                               'to_id': 'SdL6NpUSz2',
#                               'type': 'relation'}],
#                   'result_count': 0,
#                   'reviews': [],
#                   'task': 70476118,
#                   'unique_id': '0ed9f096-3e7c-450f-96f4-ed75df4c14b2',
#                   'updated_at': '2023-10-12T19:16:05.761079Z',
#                   'updated_by': 12634,
#                   'was_cancelled': False}],
#  'cancelled_annotations': 0,
#  'comment_authors': [],
#  'comment_count': 0,
#  'created_at': '2023-09-28T12:38:37.492424Z',
#  'data': {'text': 'Engelsberg Ironworks () is an ironworks in "ngelsberg", a '
#                   'village in Fagersta Municipality in Vstmanland, Sweden. It '
#                   'was built in 1681 by Per Larsson Gyllenhk (1645-1706) and '
#                   "developed into one of the world's most modern ironworks in "
#                   'the period 17001800. It is listed as a UNESCO World '
#                   'Heritage Site since 1993.Name.Engelsberg Ironworks is named '
#                   'after Englika. Englika, who was born in Germany, began '
#                   'producing iron in Engelsberg in the 14th '
#                   'century.History.The history of iron production in the '
#                   'region dates back to at least 13th century. The local '
#                   'peasants both mined the ore and produced the iron using '
#                   'primitive furnaces.',
#           'title': 'Engelsberg Ironworks'},
#  'drafts': [],
#  'file_upload': 'a7ab8cd7-engelsbergironworks.json',
#  'id': 70476118,
#  'inner_id': 2,
#  'last_comment_updated_at': None,
#  'meta': {},
#  'predictions': [],
#  'project': 41784,
#  'total_annotations': 1,
#  'total_predictions': 0,
#  'unresolved_comment_count': 0,
#  'updated_at': '2023-10-12T19:16:05.851405Z',
#  'updated_by': 12634}

# %% [markdown]
# ### 1.2 Converting to Spacy training format:
# To provide custom labels to Spacy, we need to convert the data to the following format:
#
# ```python
# training_data = [
#   ("Tokyo Tower is 333m tall.", [(0, 11, "BUILDING"), (20, 23, "HEIGHT")]),
# ]
# ```
#
# The `process_export` function from the preprocessor can fix this for us, it retrieves the training data in the given format, in combination with the labels and their relationship

# %%
training_data, training_relations = processor.process_export_sentences(training_data_export)
validation_data, validation_relations = processor.process_export_sentences(ground_truth_export, ground_truth = True)

# %% [markdown]
# #### 1.2.1 Checking results
# Now it is time to check what the results are from the process_export_sentences. The training data and training_relations will look differently and both are shown below. For all examples only the first text is used. Specifically only the first entity is shown for the entities that will be used to train the NER model. For the REL model one whole text is shown.

# %%
print("Training data info item 1 \ntext:")
print(training_data[0][0])
print("Labels:")
print(*training_data[0][1]["entities"], sep = "\n")

print("\n Validation data info item 1 \ntext:")
print(validation_data[0][0])
print("Labels:")
print(*validation_data[0][1]["entities"], sep = "\n")
# Out:
# Training data info item 1
# text:
# Engelsberg Ironworks () is an ironworks in "ngelsberg", a village in Fagersta Municipality in Vstmanland, Sweden.
# Labels:
# [0, 20, 'landmark_name']
#
#  Validation data info item 1
# text:
#  Ephesus (; ; ; may ultimately derive from ) was a city in Ancient Greece on the coast of Ionia, southwest of present-day Seluk in zmir Province, Turkey.
# Labels:
# [1, 8, 'landmark_name']

# %%
pprint(training_relations[0])
# Out:
# {'answer': 'accept',
#  'meta': {'source': 'Engelsberg Ironworks'},
#  'relations': [{'child': 6,
#                 'child_span': {'end': 39,
#                                'label': 'type',
#                                'start': 30,
#                                'token_end': 6,
#                                'token_start': 6},
#                 'head': 1,
#                 'head_span': {'end': 20,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:is_type'},
#                {'child': 9,
#                 'child_span': {'end': 53,
#                                'label': 'location',
#                                'start': 44,
#                                'token_end': 9,
#                                'token_start': 9},
#                 'head': 1,
#                 'head_span': {'end': 20,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 16,
#                 'child_span': {'end': 90,
#                                'label': 'location',
#                                'start': 69,
#                                'token_end': 16,
#                                'token_start': 15},
#                 'head': 1,
#                 'head_span': {'end': 20,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 18,
#                 'child_span': {'end': 104,
#                                'label': 'location',
#                                'start': 94,
#                                'token_end': 18,
#                                'token_start': 18},
#                 'head': 1,
#                 'head_span': {'end': 20,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 20,
#                 'child_span': {'end': 112,
#                                'label': 'location',
#                                'start': 106,
#                                'token_end': 20,
#                                'token_start': 20},
#                 'head': 1,
#                 'head_span': {'end': 20,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 26,
#                 'child_span': {'end': 134,
#                                'label': 'date',
#                                'start': 127,
#                                'token_end': 26,
#                                'token_start': 25},
#                 'head': 24,
#                 'head_span': {'end': 126,
#                               'label': 'condition',
#                               'start': 121,
#                               'token_end': 24,
#                               'token_start': 24},
#                 'label': 'org:happened_on'},
#                {'child': 46,
#                 'child_span': {'end': 230,
#                                'label': 'type',
#                                'start': 221,
#                                'token_end': 46,
#                                'token_start': 46},
#                 'head': 1,
#                 'head_span': {'end': 20,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:is_type'},
#                {'child': 50,
#                 'child_span': {'end': 253,
#                                'label': 'date',
#                                'start': 245,
#                                'token_end': 50,
#                                'token_start': 50},
#                 'head': 45,
#                 'head_span': {'end': 220,
#                               'label': 'condition',
#                               'start': 190,
#                               'token_end': 45,
#                               'token_start': 39},
#                 'label': 'org:happened_on'},
#                {'child': 24,
#                 'child_span': {'end': 126,
#                                'label': 'condition',
#                                'start': 121,
#                                'token_end': 24,
#                                'token_start': 24},
#                 'head': 22,
#                 'head_span': {'end': 116,
#                               'label': 'landmark_name',
#                               'start': 114,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:is_condition'},
#                {'child': 30,
#                 'child_span': {'end': 158,
#                                'label': 'person_name',
#                                'start': 138,
#                                'token_end': 30,
#                                'token_start': 28},
#                 'head': 22,
#                 'head_span': {'end': 116,
#                               'label': 'landmark_name',
#                               'start': 114,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:created_by'},
#                {'child': 45,
#                 'child_span': {'end': 220,
#                                'label': 'condition',
#                                'start': 190,
#                                'token_end': 45,
#                                'token_start': 39},
#                 'head': 22,
#                 'head_span': {'end': 116,
#                               'label': 'landmark_name',
#                               'start': 114,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:is_condition'},
#                {'child': 46,
#                 'child_span': {'end': 230,
#                                'label': 'type',
#                                'start': 221,
#                                'token_end': 46,
#                                'token_start': 46},
#                 'head': 22,
#                 'head_span': {'end': 116,
#                               'label': 'landmark_name',
#                               'start': 114,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:is_type'},
#                {'child': 1,
#                 'child_span': {'end': 20,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 22,
#                 'head_span': {'end': 116,
#                               'label': 'landmark_name',
#                               'start': 114,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:is_similar_to'},
#                {'child': 1,
#                 'child_span': {'end': 20,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 65,
#                 'head_span': {'end': 336,
#                               'label': 'landmark_name',
#                               'start': 316,
#                               'token_end': 65,
#                               'token_start': 64},
#                 'label': 'org:is_similar_to'},
#                {'child': 81,
#                 'child_span': {'end': 415,
#                                'label': 'component',
#                                'start': 411,
#                                'token_end': 81,
#                                'token_start': 81},
#                 'head': 83,
#                 'head_span': {'end': 429,
#                               'label': 'landmark_name',
#                               'start': 419,
#                               'token_end': 83,
#                               'token_start': 83},
#                 'label': 'org:has_component'},
#                {'child': 94,
#                 'child_span': {'end': 477,
#                                'label': 'component',
#                                'start': 473,
#                                'token_end': 94,
#                                'token_start': 94},
#                 'head': 83,
#                 'head_span': {'end': 429,
#                               'label': 'landmark_name',
#                               'start': 419,
#                               'token_end': 83,
#                               'token_start': 83},
#                 'label': 'org:has_component'},
#                {'child': 113,
#                 'child_span': {'end': 577,
#                                'label': 'component',
#                                'start': 574,
#                                'token_end': 113,
#                                'token_start': 113},
#                 'head': 83,
#                 'head_span': {'end': 429,
#                               'label': 'landmark_name',
#                               'start': 419,
#                               'token_end': 83,
#                               'token_start': 83},
#                 'label': 'org:has_component'},
#                {'child': 117,
#                 'child_span': {'end': 599,
#                                'label': 'component',
#                                'start': 595,
#                                'token_end': 117,
#                                'token_start': 117},
#                 'head': 83,
#                 'head_span': {'end': 429,
#                               'label': 'landmark_name',
#                               'start': 419,
#                               'token_end': 83,
#                               'token_start': 83},
#                 'label': 'org:has_component'},
#                {'child': 120,
#                 'child_span': {'end': 624,
#                                'label': 'component',
#                                'start': 605,
#                                'token_end': 120,
#                                'token_start': 119},
#                 'head': 83,
#                 'head_span': {'end': 429,
#                               'label': 'landmark_name',
#                               'start': 419,
#                               'token_end': 83,
#                               'token_start': 83},
#                 'label': 'org:has_component'},
#                {'child': 111,
#                 'child_span': {'end': 569,
#                                'label': 'condition',
#                                'start': 564,
#                                'token_end': 111,
#                                'token_start': 111},
#                 'head': 113,
#                 'head_span': {'end': 577,
#                               'label': 'component',
#                               'start': 574,
#                               'token_end': 113,
#                               'token_start': 113},
#                 'label': 'org:is_condition'},
#                {'child': 115,
#                 'child_span': {'end': 590,
#                                'label': 'condition',
#                                'start': 582,
#                                'token_end': 115,
#                                'token_start': 115},
#                 'head': 117,
#                 'head_span': {'end': 599,
#                               'label': 'component',
#                               'start': 595,
#                               'token_end': 117,
#                               'token_start': 117},
#                 'label': 'org:is_condition'},
#                {'child': 3,
#                 'child_span': {'end': 22,
#                                'label': 'landmark_name',
#                                'start': 4,
#                                'token_end': 3,
#                                'token_start': 1},
#                 'head': 11,
#                 'head_span': {'end': 63,
#                               'label': 'landmark_name',
#                               'start': 45,
#                               'token_end': 11,
#                               'token_start': 9},
#                 'label': 'org:is_similar_to'},
#                {'child': 17,
#                 'child_span': {'end': 84,
#                                'label': 'type',
#                                'start': 71,
#                                'token_end': 17,
#                                'token_start': 16},
#                 'head': 11,
#                 'head_span': {'end': 63,
#                               'label': 'landmark_name',
#                               'start': 45,
#                               'token_end': 11,
#                               'token_start': 9},
#                 'label': 'org:is_type'},
#                {'child': 28,
#                 'child_span': {'end': 139,
#                                'label': 'location',
#                                'start': 135,
#                                'token_end': 28,
#                                'token_start': 28},
#                 'head': 11,
#                 'head_span': {'end': 63,
#                               'label': 'landmark_name',
#                               'start': 45,
#                               'token_end': 11,
#                               'token_start': 9},
#                 'label': 'org:located_in'},
#                {'child': 33,
#                 'child_span': {'end': 162,
#                                'label': 'location',
#                                'start': 144,
#                                'token_end': 33,
#                                'token_start': 30},
#                 'head': 11,
#                 'head_span': {'end': 63,
#                               'label': 'landmark_name',
#                               'start': 45,
#                               'token_end': 11,
#                               'token_start': 9},
#                 'label': 'org:located_in'},
#                {'child': 35,
#                 'child_span': {'end': 172,
#                                'label': 'location',
#                                'start': 166,
#                                'token_end': 35,
#                                'token_start': 35},
#                 'head': 11,
#                 'head_span': {'end': 63,
#                               'label': 'landmark_name',
#                               'start': 45,
#                               'token_end': 11,
#                               'token_start': 9},
#                 'label': 'org:located_in'},
#                {'child': 3,
#                 'child_span': {'end': 22,
#                                'label': 'landmark_name',
#                                'start': 4,
#                                'token_end': 3,
#                                'token_start': 1},
#                 'head': 41,
#                 'head_span': {'end': 202,
#                               'label': 'landmark_name',
#                               'start': 189,
#                               'token_end': 41,
#                               'token_start': 40},
#                 'label': 'org:is_similar_to'},
#                {'child': 48,
#                 'child_span': {'end': 240,
#                                'label': 'location',
#                                'start': 236,
#                                'token_end': 48,
#                                'token_start': 48},
#                 'head': 41,
#                 'head_span': {'end': 202,
#                               'label': 'landmark_name',
#                               'start': 189,
#                               'token_end': 41,
#                               'token_start': 40},
#                 'label': 'org:located_in'},
#                {'child': 53,
#                 'child_span': {'end': 263,
#                                'label': 'location',
#                                'start': 245,
#                                'token_end': 53,
#                                'token_start': 50},
#                 'head': 41,
#                 'head_span': {'end': 202,
#                               'label': 'landmark_name',
#                               'start': 189,
#                               'token_end': 41,
#                               'token_start': 40},
#                 'label': 'org:located_in'},
#                {'child': 61,
#                 'child_span': {'end': 299,
#                                'label': 'location',
#                                'start': 293,
#                                'token_end': 61,
#                                'token_start': 61},
#                 'head': 41,
#                 'head_span': {'end': 202,
#                               'label': 'landmark_name',
#                               'start': 189,
#                               'token_end': 41,
#                               'token_start': 40},
#                 'label': 'org:located_in'},
#                {'child': 66,
#                 'child_span': {'end': 336,
#                                'label': 'location',
#                                'start': 301,
#                                'token_end': 66,
#                                'token_start': 63},
#                 'head': 41,
#                 'head_span': {'end': 202,
#                               'label': 'landmark_name',
#                               'start': 189,
#                               'token_end': 41,
#                               'token_start': 40},
#                 'label': 'org:located_in'},
#                {'child': 3,
#                 'child_span': {'end': 22,
#                                'label': 'landmark_name',
#                                'start': 4,
#                                'token_end': 3,
#                                'token_start': 1},
#                 'head': 68,
#                 'head_span': {'end': 340,
#                               'label': 'landmark_name',
#                               'start': 338,
#                               'token_end': 68,
#                               'token_start': 68},
#                 'label': 'org:is_similar_to'},
#                {'child': 72,
#                 'child_span': {'end': 367,
#                                'label': 'type',
#                                'start': 351,
#                                'token_end': 72,
#                                'token_start': 71},
#                 'head': 68,
#                 'head_span': {'end': 340,
#                               'label': 'landmark_name',
#                               'start': 338,
#                               'token_end': 68,
#                               'token_start': 68},
#                 'label': 'org:is_type'},
#                {'child': 75,
#                 'child_span': {'end': 377,
#                                'label': 'type',
#                                'start': 373,
#                                'token_end': 75,
#                                'token_start': 75},
#                 'head': 68,
#                 'head_span': {'end': 340,
#                               'label': 'landmark_name',
#                               'start': 338,
#                               'token_end': 68,
#                               'token_start': 68},
#                 'label': 'org:is_type'},
#                {'child': 81,
#                 'child_span': {'end': 414,
#                                'label': 'location',
#                                'start': 388,
#                                'token_end': 81,
#                                'token_start': 79},
#                 'head': 68,
#                 'head_span': {'end': 340,
#                               'label': 'landmark_name',
#                               'start': 338,
#                               'token_end': 68,
#                               'token_start': 68},
#                 'label': 'org:located_in'},
#                {'child': 6,
#                 'child_span': {'end': 34,
#                                'label': 'condition',
#                                'start': 19,
#                                'token_end': 6,
#                                'token_start': 4},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:is_condition'},
#                {'child': 11,
#                 'child_span': {'end': 56,
#                                'label': 'type',
#                                'start': 44,
#                                'token_end': 11,
#                                'token_start': 10},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:is_type'},
#                {'child': 9,
#                 'child_span': {'end': 43,
#                                'label': 'condition',
#                                'start': 35,
#                                'token_end': 9,
#                                'token_start': 7},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:is_condition'},
#                {'child': 13,
#                 'child_span': {'end': 74,
#                                'label': 'component',
#                                'start': 62,
#                                'token_end': 13,
#                                'token_start': 13},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:has_component'},
#                {'child': 27,
#                 'child_span': {'end': 156,
#                                'label': 'location',
#                                'start': 137,
#                                'token_end': 27,
#                                'token_start': 26},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 29,
#                 'child_span': {'end': 171,
#                                'label': 'location',
#                                'start': 160,
#                                'token_end': 29,
#                                'token_start': 29},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 31,
#                 'child_span': {'end': 178,
#                                'label': 'location',
#                                'start': 173,
#                                'token_end': 31,
#                                'token_start': 31},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:is_similar_to'},
#                {'child': 37,
#                 'child_span': {'end': 204,
#                                'label': 'component',
#                                'start': 199,
#                                'token_end': 37,
#                                'token_start': 37},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:has_component'},
#                {'child': 43,
#                 'child_span': {'end': 231,
#                                'label': 'condition',
#                                'start': 222,
#                                'token_end': 43,
#                                'token_start': 43},
#                 'head': 37,
#                 'head_span': {'end': 204,
#                               'label': 'component',
#                               'start': 199,
#                               'token_end': 37,
#                               'token_start': 37},
#                 'label': 'org:is_condition'},
#                {'child': 47,
#                 'child_span': {'end': 254,
#                                'label': 'component',
#                                'start': 241,
#                                'token_end': 47,
#                                'token_start': 46},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:has_component'},
#                {'child': 51,
#                 'child_span': {'end': 279,
#                                'label': 'location',
#                                'start': 262,
#                                'token_end': 51,
#                                'token_start': 50},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:located_in'},
#                {'child': 67,
#                 'child_span': {'end': 345,
#                                'label': 'component',
#                                'start': 340,
#                                'token_end': 67,
#                                'token_start': 67},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:has_component'},
#                {'child': 74,
#                 'child_span': {'end': 371,
#                                'label': 'component',
#                                'start': 366,
#                                'token_end': 74,
#                                'token_start': 74},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:has_component'},
#                {'child': 81,
#                 'child_span': {'end': 394,
#                                'label': 'component',
#                                'start': 389,
#                                'token_end': 81,
#                                'token_start': 81},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:has_component'},
#                {'child': 84,
#                 'child_span': {'end': 406,
#                                'label': 'component',
#                                'start': 401,
#                                'token_end': 84,
#                                'token_start': 84},
#                 'head': 40,
#                 'head_span': {'end': 216,
#                               'label': 'landmark_name',
#                               'start': 212,
#                               'token_end': 40,
#                               'token_start': 40},
#                 'label': 'org:has_component'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 137,
#                 'head_span': {'end': 723,
#                               'label': 'landmark_name',
#                               'start': 711,
#                               'token_end': 137,
#                               'token_start': 136},
#                 'label': 'org:is_similar_to'},
#                {'child': 147,
#                 'child_span': {'end': 780,
#                                'label': 'date',
#                                'start': 776,
#                                'token_end': 147,
#                                'token_start': 147},
#                 'head': 137,
#                 'head_span': {'end': 723,
#                               'label': 'landmark_name',
#                               'start': 711,
#                               'token_end': 137,
#                               'token_start': 136},
#                 'label': 'org:enlisted_in'},
#                {'child': 8,
#                 'child_span': {'end': 52,
#                                'label': 'type',
#                                'start': 40,
#                                'token_end': 8,
#                                'token_start': 7},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:is_type'},
#                {'child': 15,
#                 'child_span': {'end': 99,
#                                'label': 'person_name',
#                                'start': 94,
#                                'token_end': 15,
#                                'token_start': 15},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:created_by'},
#                {'child': 31,
#                 'child_span': {'end': 186,
#                                'label': 'location',
#                                'start': 170,
#                                'token_end': 31,
#                                'token_start': 30},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:located_in'},
#                {'child': 35,
#                 'child_span': {'end': 201,
#                                'label': 'location',
#                                'start': 192,
#                                'token_end': 35,
#                                'token_start': 35},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:located_in'},
#                {'child': 50,
#                 'child_span': {'end': 261,
#                                'label': 'location',
#                                'start': 247,
#                                'token_end': 50,
#                                'token_start': 49},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:located_in'},
#                {'child': 54,
#                 'child_span': {'end': 277,
#                                'label': 'location',
#                                'start': 271,
#                                'token_end': 54,
#                                'token_start': 54},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:located_in'},
#                {'child': 60,
#                 'child_span': {'end': 310,
#                                'label': 'location',
#                                'start': 301,
#                                'token_end': 60,
#                                'token_start': 60},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:located_in'},
#                {'child': 71,
#                 'child_span': {'end': 363,
#                                'label': 'location',
#                                'start': 342,
#                                'token_end': 71,
#                                'token_start': 69},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:located_in'},
#                {'child': 77,
#                 'child_span': {'end': 393,
#                                'label': 'component',
#                                'start': 382,
#                                'token_end': 77,
#                                'token_start': 76},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:has_component'},
#                {'child': 83,
#                 'child_span': {'end': 422,
#                                'label': 'component',
#                                'start': 401,
#                                'token_end': 83,
#                                'token_start': 81},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:has_component'},
#                {'child': 96,
#                 'child_span': {'end': 484,
#                                'label': 'component',
#                                'start': 470,
#                                'token_end': 96,
#                                'token_start': 95},
#                 'head': 2,
#                 'head_span': {'end': 19,
#                               'label': 'landmark_name',
#                               'start': 4,
#                               'token_end': 2,
#                               'token_start': 1},
#                 'label': 'org:has_component'},
#                {'child': 99,
#                 'child_span': {'end': 501,
#                                'label': 'component',
#                                'start': 490,
#                                'token_end': 99,
#                                'token_start': 98},
#                 'head': 96,
#                 'head_span': {'end': 484,
#                               'label': 'component',
#                               'start': 470,
#                               'token_end': 96,
#                               'token_start': 95},
#                 'label': 'org:has_component'},
#                {'child': 8,
#                 'child_span': {'end': 54,
#                                'label': 'location',
#                                'start': 40,
#                                'token_end': 8,
#                                'token_start': 7},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 12,
#                 'child_span': {'end': 77,
#                                'label': 'location',
#                                'start': 62,
#                                'token_end': 12,
#                                'token_start': 11},
#                 'head': 1,
#                 'head_span': {'end': 12,
#                               'label': 'landmark_name',
#                               'start': 0,
#                               'token_end': 1,
#                               'token_start': 0},
#                 'label': 'org:located_in'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 22,
#                 'head_span': {'end': 135,
#                               'label': 'landmark_name',
#                               'start': 128,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:is_similar_to'},
#                {'child': 26,
#                 'child_span': {'end': 157,
#                                'label': 'condition',
#                                'start': 143,
#                                'token_end': 26,
#                                'token_start': 25},
#                 'head': 22,
#                 'head_span': {'end': 135,
#                               'label': 'landmark_name',
#                               'start': 128,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:is_condition'},
#                {'child': 28,
#                 'child_span': {'end': 169,
#                                'label': 'type',
#                                'start': 158,
#                                'token_end': 28,
#                                'token_start': 27},
#                 'head': 22,
#                 'head_span': {'end': 135,
#                               'label': 'landmark_name',
#                               'start': 128,
#                               'token_end': 22,
#                               'token_start': 22},
#                 'label': 'org:is_type'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 37,
#                 'head_span': {'end': 211,
#                               'label': 'landmark_name',
#                               'start': 199,
#                               'token_end': 37,
#                               'token_start': 36},
#                 'label': 'org:is_similar_to'},
#                {'child': 40,
#                 'child_span': {'end': 235,
#                                'label': 'component',
#                                'start': 224,
#                                'token_end': 40,
#                                'token_start': 39},
#                 'head': 37,
#                 'head_span': {'end': 211,
#                               'label': 'landmark_name',
#                               'start': 199,
#                               'token_end': 37,
#                               'token_start': 36},
#                 'label': 'org:has_component'},
#                {'child': 44,
#                 'child_span': {'end': 265,
#                                'label': 'component',
#                                'start': 250,
#                                'token_end': 44,
#                                'token_start': 43},
#                 'head': 40,
#                 'head_span': {'end': 235,
#                               'label': 'component',
#                               'start': 224,
#                               'token_end': 40,
#                               'token_start': 39},
#                 'label': 'org:has_component'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 55,
#                 'head_span': {'end': 322,
#                               'label': 'landmark_name',
#                               'start': 310,
#                               'token_end': 55,
#                               'token_start': 54},
#                 'label': 'org:is_similar_to'},
#                {'child': 63,
#                 'child_span': {'end': 362,
#                                'label': 'condition',
#                                'start': 330,
#                                'token_end': 63,
#                                'token_start': 58},
#                 'head': 55,
#                 'head_span': {'end': 322,
#                               'label': 'landmark_name',
#                               'start': 310,
#                               'token_end': 55,
#                               'token_start': 54},
#                 'label': 'org:is_condition'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 81,
#                 'head_span': {'end': 461,
#                               'label': 'landmark_name',
#                               'start': 454,
#                               'token_end': 81,
#                               'token_start': 81},
#                 'label': 'org:is_similar_to'},
#                {'child': 87,
#                 'child_span': {'end': 496,
#                                'label': 'location',
#                                'start': 481,
#                                'token_end': 87,
#                                'token_start': 86},
#                 'head': 81,
#                 'head_span': {'end': 461,
#                               'label': 'landmark_name',
#                               'start': 454,
#                               'token_end': 81,
#                               'token_start': 81},
#                 'label': 'org:located_in'},
#                {'child': 95,
#                 'child_span': {'end': 543,
#                                'label': 'location',
#                                'start': 528,
#                                'token_end': 95,
#                                'token_start': 94},
#                 'head': 81,
#                 'head_span': {'end': 461,
#                               'label': 'landmark_name',
#                               'start': 454,
#                               'token_end': 81,
#                               'token_start': 81},
#                 'label': 'org:located_in'},
#                {'child': 104,
#                 'child_span': {'end': 584,
#                                'label': 'condition',
#                                'start': 568,
#                                'token_end': 104,
#                                'token_start': 103},
#                 'head': 100,
#                 'head_span': {'end': 560,
#                               'label': 'landmark_name',
#                               'start': 558,
#                               'token_end': 100,
#                               'token_start': 100},
#                 'label': 'org:is_condition'},
#                {'child': 106,
#                 'child_span': {'end': 596,
#                                'label': 'type',
#                                'start': 585,
#                                'token_end': 106,
#                                'token_start': 105},
#                 'head': 100,
#                 'head_span': {'end': 560,
#                               'label': 'landmark_name',
#                               'start': 558,
#                               'token_end': 100,
#                               'token_start': 100},
#                 'label': 'org:is_type'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 100,
#                 'head_span': {'end': 560,
#                               'label': 'landmark_name',
#                               'start': 558,
#                               'token_end': 100,
#                               'token_start': 100},
#                 'label': 'org:is_similar_to'},
#                {'child': 1,
#                 'child_span': {'end': 12,
#                                'label': 'landmark_name',
#                                'start': 0,
#                                'token_end': 1,
#                                'token_start': 0},
#                 'head': 113,
#                 'head_span': {'end': 625,
#                               'label': 'landmark_name',
#                               'start': 623,
#                               'token_end': 113,
#                               'token_start': 113},
#                 'label': 'org:is_similar_to'},
#                {'child': 119,
#                 'child_span': {'end': 656,
#                                'label': 'component',
#                                'start': 650,
#                                'token_end': 119,
#                                'token_start': 119},
#                 'head': 113,
#                 'head_span': {'end': 625,
#                               'label': 'landmark_name',
#                               'start': 623,
#                               'token_end': 113,
#                               'token_start': 113},
#                 'label': 'org:has_component'},
# ...
#             'text': 'Per Larsson Gyllenhk',
#             'token_end': 30,
#             'token_start': 28,
#             'type': 'span'},
#            {'end': 169,
#             'label': 'date',
#             'start': 160,
#             'text': '1645-1706',
#             'token_end': 34,
#             'token_start': 32,
#             'type': 'span'},
#            {'end': 220,
#             'label': 'condition',
#             'start': 190,
#             'text': "one of the world's most modern",
#             'token_end': 45,
#             'token_start': 39,
#             'type': 'span'},
#            {'end': 230,
#             'label': 'type',
#             'start': 221,
#             'text': 'ironworks',
#             'token_end': 46,
#             'token_start': 46,
#             'type': 'span'},
#            {'end': 253,
#             'label': 'date',
#             'start': 245,
#             'text': '17001800',
#             'token_end': 50,
#             'token_start': 50,
#             'type': 'span'},
#            {'end': 310,
#             'label': 'date',
#             'start': 300,
#             'text': 'since 1993',
#             'token_end': 61,
#             'token_start': 61,
#             'type': 'span'},
#            {'end': 336,
#             'label': 'landmark_name',
#             'start': 316,
#             'text': 'Engelsberg Ironworks',
#             'token_end': 65,
#             'token_start': 64,
#             'type': 'span'},
#            {'end': 359,
#             'label': 'person_name',
#             'start': 352,
#             'text': 'Englika',
#             'token_end': 69,
#             'token_start': 69,
#             'type': 'span'},
#            {'end': 368,
#             'label': 'person_name',
#             'start': 361,
#             'text': 'Englika',
#             'token_end': 71,
#             'token_start': 71,
#             'type': 'span'},
#            {'end': 393,
#             'label': 'location',
#             'start': 386,
#             'text': 'Germany',
#             'token_end': 77,
#             'token_start': 77,
#             'type': 'span'},
#            {'end': 415,
#             'label': 'component',
#             'start': 411,
#             'text': 'iron',
#             'token_end': 81,
#             'token_start': 81,
#             'type': 'span'},
#            {'end': 429,
#             'label': 'landmark_name',
#             'start': 419,
#             'text': 'Engelsberg',
#             'token_end': 83,
#             'token_start': 83,
#             'type': 'span'},
#            {'end': 449,
#             'label': 'date',
#             'start': 430,
#             'text': 'in the 14th century',
#             'token_end': 87,
#             'token_start': 84,
#             'type': 'span'},
#            {'end': 538,
#             'label': 'date',
#             'start': 517,
#             'text': 'at least 13th century',
#             'token_end': 105,
#             'token_start': 102,
#             'type': 'span'},
#            {'end': 558,
#             'label': 'people',
#             'start': 544,
#             'text': 'local peasants',
#             'token_end': 109,
#             'token_start': 108,
#             'type': 'span'},
#            {'end': 624,
#             'label': 'component',
#             'start': 605,
#             'text': ' primitive furnaces',
#             'token_end': 120,
#             'token_start': 119,
#             'type': 'span'},
#            {'end': 577,
#             'label': 'component',
#             'start': 574,
#             'text': 'ore',
#             'token_end': 113,
#             'token_start': 113,
#             'type': 'span'},
#            {'end': 599,
#             'label': 'component',
#             'start': 595,
#             'text': 'iron',
#             'token_end': 117,
#             'token_start': 117,
#             'type': 'span'},
#            {'end': 477,
#             'label': 'component',
#             'start': 473,
#             'text': 'iron',
#             'token_end': 94,
#             'token_start': 94,
#             'type': 'span'},
#            {'end': 116,
#             'label': 'landmark_name',
#             'start': 114,
#             'text': 'It',
#             'token_end': 22,
#             'token_start': 22,
#             'type': 'span'},
#            {'end': 569,
#             'label': 'condition',
#             'start': 564,
#             'text': 'mined',
#             'token_end': 111,
#             'token_start': 111,
#             'type': 'span'},
#            {'end': 590,
#             'label': 'condition',
#             'start': 582,
#             'text': 'produced',
#             'token_end': 115,
#             'token_start': 115,
#             'type': 'span'}],
#  'text': 'Engelsberg Ironworks () is an ironworks in "ngelsberg", a village in '
#          'Fagersta Municipality in Vstmanland, Sweden. It was built in 1681 by '
#          'Per Larsson Gyllenhk (1645-1706) and developed into one of the '
#          "world's most modern ironworks in the period 17001800. It is listed "
#          'as a UNESCO World Heritage Site since 1993.Name.Engelsberg Ironworks '
#          'is named after Englika. Englika, who was born in Germany, began '
#          'producing iron in Engelsberg in the 14th century.History.The history '
#          'of iron production in the region dates back to at least 13th '
#          'century. The local peasants both mined the ore and produced the iron '
#          'using primitive furnaces.',
#  'tokens': [{'end': 10, 'id': 0, 'start': 0, 'text': 'Engelsberg', 'ws': True},
#             {'end': 20, 'id': 1, 'start': 11, 'text': 'Ironworks', 'ws': True},
#             {'end': 22, 'id': 2, 'start': 21, 'text': '(', 'ws': False},
#             {'end': 23, 'id': 3, 'start': 22, 'text': ')', 'ws': True},
#             {'end': 26, 'id': 4, 'start': 24, 'text': 'is', 'ws': True},
#             {'end': 29, 'id': 5, 'start': 27, 'text': 'an', 'ws': True},
#             {'end': 39, 'id': 6, 'start': 30, 'text': 'ironworks', 'ws': True},
#             {'end': 42, 'id': 7, 'start': 40, 'text': 'in', 'ws': True},
#             {'end': 44, 'id': 8, 'start': 43, 'text': '"', 'ws': False},
#             {'end': 53, 'id': 9, 'start': 44, 'text': 'ngelsberg', 'ws': False},
#             {'end': 54, 'id': 10, 'start': 53, 'text': '"', 'ws': False},
#             {'end': 55, 'id': 11, 'start': 54, 'text': ',', 'ws': True},
#             {'end': 57, 'id': 12, 'start': 56, 'text': 'a', 'ws': True},
#             {'end': 65, 'id': 13, 'start': 58, 'text': 'village', 'ws': True},
#             {'end': 68, 'id': 14, 'start': 66, 'text': 'in', 'ws': True},
#             {'end': 77, 'id': 15, 'start': 69, 'text': 'Fagersta', 'ws': True},
#             {'end': 90,
#              'id': 16,
#              'start': 78,
#              'text': 'Municipality',
#              'ws': True},
#             {'end': 93, 'id': 17, 'start': 91, 'text': 'in', 'ws': True},
#             {'end': 104,
#              'id': 18,
#              'start': 94,
#              'text': 'Vstmanland',
#              'ws': False},
#             {'end': 105, 'id': 19, 'start': 104, 'text': ',', 'ws': True},
#             {'end': 112, 'id': 20, 'start': 106, 'text': 'Sweden', 'ws': False},
#             {'end': 113, 'id': 21, 'start': 112, 'text': '.', 'ws': True},
#             {'end': 116, 'id': 22, 'start': 114, 'text': 'It', 'ws': True},
#             {'end': 120, 'id': 23, 'start': 117, 'text': 'was', 'ws': True},
#             {'end': 126, 'id': 24, 'start': 121, 'text': 'built', 'ws': True},
#             {'end': 129, 'id': 25, 'start': 127, 'text': 'in', 'ws': True},
#             {'end': 134, 'id': 26, 'start': 130, 'text': '1681', 'ws': True},
#             {'end': 137, 'id': 27, 'start': 135, 'text': 'by', 'ws': True},
#             {'end': 141, 'id': 28, 'start': 138, 'text': 'Per', 'ws': True},
#             {'end': 149, 'id': 29, 'start': 142, 'text': 'Larsson', 'ws': True},
#             {'end': 158,
#              'id': 30,
#              'start': 150,
#              'text': 'Gyllenhk',
#              'ws': True},
#             {'end': 160, 'id': 31, 'start': 159, 'text': '(', 'ws': False},
#             {'end': 164, 'id': 32, 'start': 160, 'text': '1645', 'ws': False},
#             {'end': 165, 'id': 33, 'start': 164, 'text': '-', 'ws': False},
#             {'end': 169, 'id': 34, 'start': 165, 'text': '1706', 'ws': False},
#             {'end': 170, 'id': 35, 'start': 169, 'text': ')', 'ws': True},
#             {'end': 174, 'id': 36, 'start': 171, 'text': 'and', 'ws': True},
#             {'end': 184,
#              'id': 37,
#              'start': 175,
#              'text': 'developed',
#              'ws': True},
#             {'end': 189, 'id': 38, 'start': 185, 'text': 'into', 'ws': True},
#             {'end': 193, 'id': 39, 'start': 190, 'text': 'one', 'ws': True},
#             {'end': 196, 'id': 40, 'start': 194, 'text': 'of', 'ws': True},
#             {'end': 200, 'id': 41, 'start': 197, 'text': 'the', 'ws': True},
#             {'end': 206, 'id': 42, 'start': 201, 'text': 'world', 'ws': False},
#             {'end': 208, 'id': 43, 'start': 206, 'text': "'s", 'ws': True},
#             {'end': 213, 'id': 44, 'start': 209, 'text': 'most', 'ws': True},
#             {'end': 220, 'id': 45, 'start': 214, 'text': 'modern', 'ws': True},
#             {'end': 230,
#              'id': 46,
#              'start': 221,
#              'text': 'ironworks',
#              'ws': True},
#             {'end': 233, 'id': 47, 'start': 231, 'text': 'in', 'ws': True},
#             {'end': 237, 'id': 48, 'start': 234, 'text': 'the', 'ws': True},
#             {'end': 244, 'id': 49, 'start': 238, 'text': 'period', 'ws': True},
#             {'end': 253,
#              'id': 50,
#              'start': 245,
#              'text': '17001800',
#              'ws': False},
#             {'end': 254, 'id': 51, 'start': 253, 'text': '.', 'ws': True},
#             {'end': 257, 'id': 52, 'start': 255, 'text': 'It', 'ws': True},
#             {'end': 260, 'id': 53, 'start': 258, 'text': 'is', 'ws': True},
#             {'end': 267, 'id': 54, 'start': 261, 'text': 'listed', 'ws': True},
#             {'end': 270, 'id': 55, 'start': 268, 'text': 'as', 'ws': True},
#             {'end': 272, 'id': 56, 'start': 271, 'text': 'a', 'ws': True},
#             {'end': 279, 'id': 57, 'start': 273, 'text': 'UNESCO', 'ws': True},
#             {'end': 285, 'id': 58, 'start': 280, 'text': 'World', 'ws': True},
#             {'end': 294,
#              'id': 59,
#              'start': 286,
#              'text': 'Heritage',
#              'ws': True},
#             {'end': 299, 'id': 60, 'start': 295, 'text': 'Site', 'ws': True},
#             {'end': 305, 'id': 61, 'start': 300, 'text': 'since', 'ws': True},
#             {'end': 315,
#              'id': 62,
#              'start': 306,
#              'text': '1993.Name',
#              'ws': False},
#             {'end': 316, 'id': 63, 'start': 315, 'text': '.', 'ws': False},
#             {'end': 326,
#              'id': 64,
#              'start': 316,
#              'text': 'Engelsberg',
#              'ws': True},
#             {'end': 336,
#              'id': 65,
#              'start': 327,
#              'text': 'Ironworks',
#              'ws': True},
#             {'end': 339, 'id': 66, 'start': 337, 'text': 'is', 'ws': True},
#             {'end': 345, 'id': 67, 'start': 340, 'text': 'named', 'ws': True},
#             {'end': 351, 'id': 68, 'start': 346, 'text': 'after', 'ws': True},
#             {'end': 359,
#              'id': 69,
#              'start': 352,
#              'text': 'Englika',
#              'ws': False},
#             {'end': 360, 'id': 70, 'start': 359, 'text': '.', 'ws': True},
#             {'end': 368,
#              'id': 71,
#              'start': 361,
#              'text': 'Englika',
#              'ws': False},
#             {'end': 369, 'id': 72, 'start': 368, 'text': ',', 'ws': True},
#             {'end': 373, 'id': 73, 'start': 370, 'text': 'who', 'ws': True},
#             {'end': 377, 'id': 74, 'start': 374, 'text': 'was', 'ws': True},
#             {'end': 382, 'id': 75, 'start': 378, 'text': 'born', 'ws': True},
#             {'end': 385, 'id': 76, 'start': 383, 'text': 'in', 'ws': True},
#             {'end': 393,
#              'id': 77,
#              'start': 386,
#              'text': 'Germany',
#              'ws': False},
#             {'end': 394, 'id': 78, 'start': 393, 'text': ',', 'ws': True},
#             {'end': 400, 'id': 79, 'start': 395, 'text': 'began', 'ws': True},
#             {'end': 410,
#              'id': 80,
#              'start': 401,
#              'text': 'producing',
#              'ws': True},
#             {'end': 415, 'id': 81, 'start': 411, 'text': 'iron', 'ws': True},
#             {'end': 418, 'id': 82, 'start': 416, 'text': 'in', 'ws': True},
#             {'end': 429,
#              'id': 83,
#              'start': 419,
#              'text': 'Engelsberg',
#              'ws': True},
#             {'end': 432, 'id': 84, 'start': 430, 'text': 'in', 'ws': True},
#             {'end': 436, 'id': 85, 'start': 433, 'text': 'the', 'ws': True},
#             {'end': 441, 'id': 86, 'start': 437, 'text': '14th', 'ws': True},
#             {'end': 449,
#              'id': 87,
#              'start': 442,
#              'text': 'century',
#              'ws': False},
#             {'end': 450, 'id': 88, 'start': 449, 'text': '.', 'ws': False},
#             {'end': 457,
#              'id': 89,
#              'start': 450,
#              'text': 'History',
#              'ws': False},
#             {'end': 458, 'id': 90, 'start': 457, 'text': '.', 'ws': False},
#             {'end': 461, 'id': 91, 'start': 458, 'text': 'The', 'ws': True},
#             {'end': 469, 'id': 92, 'start': 462, 'text': 'history', 'ws': True},
#             {'end': 472, 'id': 93, 'start': 470, 'text': 'of', 'ws': True},
#             {'end': 477, 'id': 94, 'start': 473, 'text': 'iron', 'ws': True},
#             {'end': 488,
#              'id': 95,
#              'start': 478,
#              'text': 'production',
#              'ws': True},
#             {'end': 491, 'id': 96, 'start': 489, 'text': 'in', 'ws': True},
#             {'end': 495, 'id': 97, 'start': 492, 'text': 'the', 'ws': True},
#             {'end': 502, 'id': 98, 'start': 496, 'text': 'region', 'ws': True},
#             {'end': 508, 'id': 99, 'start': 503, 'text': 'dates', 'ws': True},
#             {'end': 513, 'id': 100, 'start': 509, 'text': 'back', 'ws': True},
#             {'end': 516, 'id': 101, 'start': 514, 'text': 'to', 'ws': True},
#             {'end': 519, 'id': 102, 'start': 517, 'text': 'at', 'ws': True},
#             {'end': 525, 'id': 103, 'start': 520, 'text': 'least', 'ws': True},
#             {'end': 530, 'id': 104, 'start': 526, 'text': '13th', 'ws': True},
#             {'end': 538,
#              'id': 105,
#              'start': 531,
#              'text': 'century',
#              'ws': False},
#             {'end': 539, 'id': 106, 'start': 538, 'text': '.', 'ws': True},
#             {'end': 543, 'id': 107, 'start': 540, 'text': 'The', 'ws': True},
#             {'end': 549, 'id': 108, 'start': 544, 'text': 'local', 'ws': True},
#             {'end': 558,
#              'id': 109,
#              'start': 550,
#              'text': 'peasants',
#              'ws': True},
#             {'end': 563, 'id': 110, 'start': 559, 'text': 'both', 'ws': True},
#             {'end': 569, 'id': 111, 'start': 564, 'text': 'mined', 'ws': True},
#             {'end': 573, 'id': 112, 'start': 570, 'text': 'the', 'ws': True},
#             {'end': 577, 'id': 113, 'start': 574, 'text': 'ore', 'ws': True},
#             {'end': 581, 'id': 114, 'start': 578, 'text': 'and', 'ws': True},
#             {'end': 590,
#              'id': 115,
#              'start': 582,
#              'text': 'produced',
#              'ws': True},
#             {'end': 594, 'id': 116, 'start': 591, 'text': 'the', 'ws': True},
#             {'end': 599, 'id': 117, 'start': 595, 'text': 'iron', 'ws': True},
#             {'end': 605, 'id': 118, 'start': 600, 'text': 'using', 'ws': True},
#             {'end': 615,
#              'id': 119,
#              'start': 606,
#              'text': 'primitive',
#              'ws': True},
#             {'end': 624,
#              'id': 120,
#              'start': 616,
#              'text': 'furnaces',
#              'ws': False},
#             {'end': 625, 'id': 121, 'start': 624, 'text': '.', 'ws': False}]}

# %% [markdown]
# ### 1.3 Preparing the data for Spacy
# The data is now in the correct format, so it can be processed and saved as Spacy training file using the `preprocess_spacy` function from the `Preprocessor` class.

# %%
processor.preprocess_json(training_data = training_data, validation_data = validation_data, train_path = NER_TRAIN, dev_path = NER_DEV)

# %%
processor.preprocess_json_rel(relational_annotations_train = training_relations, relational_annotations_val = validation_relations, save_path_train=REL_ASSETS_TRAIN, save_path_dev=REL_ASSETS_DEV)

# %% [markdown]
# # 2 Training the Spacy Model on on the training file
#
# For training Spacy is used. This is a good way to implement our own data into a specific model. Spacy works out of the box, but not with our specific labels and/or relations. The default behaviour of spacy looks like the following:

# %% [markdown]
# ### 2.1 Spacy before training with custom labels

# %%
import spacy
from spacy import displacy

example_text = training_data[0][0]

nlp = spacy.load("en_core_web_sm")
doc = nlp(example_text)

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Engelsberg Ironworks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  () is an ironworks in &quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ngelsberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# &quot;, a village in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fagersta Municipality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vstmanland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sweden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %% [markdown]
# ### 2.2 Training a spacy NER model
# Training of a spacy model usually is done via the command line. This is the reason for the following no so understandable lines of code. There are a few steps in the training process:
# 1. The spacy model needs a config file and all necessary files are in the spacy folder
# 2. The model needs training data, which was exported in this file above to the spacy folder
# 3. After training the model is evaluated and the results are printed for training and evaluation

# %%
from ner_model.scripts.convert import convert as ner_convert

ner_convert("en", NER_TRAIN, NER_TRAIN_CORP)
ner_convert("en", NER_DEV, NER_DEV_CORP)
# Out:
# Start converting NER data...
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [45, 55, date] in the following text because the character span 'since 1993' does not align with token boundaries:
#
# 'It is listed as a UNESCO World Heritage Site since 1993.Name.Engelsberg Ironworks is named after Englika.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [31, 37, number] in the following text because the character span 'seven ' does not align with token boundaries:
#
# 'In total, the site consists of seven component parts  Kintrishi-Mtirala and Ispani in Adjara, Grigoleti and Imnati in Guria, and Pitshora, Nabada, and Churia in Samegrelo-Zemo Svaneti.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 5, landmark_name] in the following text because the character span 'They ' does not align with token boundaries:
#
# 'They represent the work of the Pskov School that drew from the Byzantine and Novgorod traditions, fused them with the local vernacular tradition, and adjusted the architecture to the use of local resources.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [7, 19, condition] in the following text because the character span 'established ' does not align with token boundaries:
#
# 'It was established in 1973 as the Royal Chitwan National Park and was granted the status of a World Heritage Site in 1984.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [47, 97, landmark_name] in the following text because the character span 'Tiger Conservation Unit (TCU) Chitwan-Parsa-Valmik' does not align with token boundaries:
#
# 'The coherent protected area of represents the "Tiger Conservation Unit (TCU) Chitwan-Parsa-Valmiki", which covers a huge block of alluvial grasslands and subtropical moist deciduous forests.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [3, 59, landmark_name] in the following text because the character span ' Capital Cities and Tombs of the Ancient Koguryo Kingdom' does not align with token boundaries:
#
# "The Capital Cities and Tombs of the Ancient Koguryo Kingdom is an UNESCO World Heritage Site which includes a number of archaeological sites currently in Ji'an, Jilin Province and Huanren, Liaoning Province in Northeast China."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [3, 10, type] in the following text because the character span ' forest' does not align with token boundaries:
#
# "The forest is home to 800 European bison, Europe's heaviest land animal."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 12, landmark_name] in the following text because the character span 'estates ' does not align with token boundaries:
#
# 'The estates also provide exceptional examples of new urban and architectural typologies, featuring fresh design solutions, as well as technical and aesthetic innovations.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [16, 21, landmark_name] in the following text because the character span 'park ' does not align with token boundaries:
#
# 'The area of the park is , making it the largest European hillside park, and second largest park on a hill slope in the world.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 13, condition] in the following text because the character span 'Construction ' does not align with token boundaries:
#
# 'Construction of the "Bergpark", or "mountain park", began in 1689 at the behest of the Landgraves of Hesse-Kassel and took about 150 years.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 9, landmark_name] in the following text because the character span 'park ' does not align with token boundaries:
#
# 'The park is open to the public today.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [13, 21, landmark_name] in the following text because the character span 'complex ' does not align with token boundaries:
#
# 'However, the complex lacks in visitor information.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [13, 22, type] in the following text because the character span 'exhibits ' does not align with token boundaries:
#
# 'There are no exhibits or brochures available to learn more about this large space or guides at hand to provide further details, so people either need to go on a tour or explore on their own.History of Bahla Fort.The fort is believed to have been built between the 12th and 15th century by the Banu Nebhan tribe who inhabited the area at the time and were known for controlling the trade of frankincense at the time.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 6, landmark_name] in the following text because the character span 'Bagan ' does not align with token boundaries:
#
# 'Bagan (, ; formerly Pagan) is an ancient city and a UNESCO World Heritage Site in the Mandalay Region of Myanmar.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [27, 63, date] in the following text because the character span ' between the 11th and 13th centuries' does not align with token boundaries:
#
# "During the kingdom's height between the 11th and 13th centuries, more than 10,000 Buddhist temples, pagodas and monasteries were constructed in the Bagan plains alone, of which the remains of over 2200 temples and pagodas survive."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 8, landmark_name] in the following text because the character span 'Baalbek ' does not align with token boundaries:
#
# "Baalbek (; ; Syriac-Aramaic: ) is a city located east of the Litani River in Lebanon's Beqaa Valley, about northeast of Beirut."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 3, landmark_name] in the following text because the character span 'It ' does not align with token boundaries:
#
# 'It is the capital of Baalbek-Hermel Governorate.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [58, 62, date] in the following text because the character span '1982' does not align with token boundaries:
#
# 'This quarter was named a World Heritage Site by UNESCO in 1982.Built on the site of an Etruscan settlement, Florence, the symbol of the Renaissance, rose to economic and cultural pre-eminence under the Medici in the 15th and 16th centuries.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [3, 22, landmark_name] in the following text because the character span ' Old Towns of Djenn' does not align with token boundaries:
#
# 'The Old Towns of Djenn (, ) is an archaeological and urban ensemble located in the city of Djenn, in Mali.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 9, landmark_name] in the following text because the character span 'park ' does not align with token boundaries:
#
# 'The park is an area of significant volcanic activity.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 9, component] in the following text because the character span 'Features ' does not align with token boundaries:
#
# 'Features within the park include the Valley of Desolation, a region of boiling mud ponds and small geysers; the Boiling Lake; Titou Gorge; and Emerald Pool.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 13, component] in the following text because the character span 'mountain ' does not align with token boundaries:
#
# 'The mountain is the second-highest peak in Dominica, being exceeded only by Morne Diablotins ().'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 7, landmark_name] in the following text because the character span 'Masada ' does not align with token boundaries:
#
# 'Masada ( \', "fortress") is an ancient fortification in the Southern District of Israel situated on top of an isolated rock plateau, akin to a mesa.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 3, landmark_name] in the following text because the character span 'It ' does not align with token boundaries:
#
# 'It is located on the eastern edge of the Judaean Desert, overlooking the Dead Sea east of Arad.Herod the Great built two palaces for himself on the mountain and fortified Masada between 37 and 31 BCE.According to Josephus, the siege of Masada by Roman troops from 73 to 74 CE, at the end of the First JewishRoman War, ended in the mass suicide of the 960 Sicarii rebels who were hiding there.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 3, landmark_name] in the following text because the character span 'It ' does not align with token boundaries:
#
# 'It protects a diverse number of ecosystems including lowland rainforests, cloud forests and Andean grasslands.History.Man National Park was established by decree on 29 May 1973; during the dictatorship of General Juan Velasco.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 3, landmark_name] in the following text because the character span 'It ' does not align with token boundaries:
#
# 'It covers an area of 42.47km, approximately 9% of the total area of Andorra, and is part of the second largest watershed basin in Andorra.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 9, landmark_name] in the following text because the character span 'site ' does not align with token boundaries:
#
# 'The site includes 3 contiguous national parks within the humid tropical forests of Central Africa: Nouabal-Ndoki National Park in Congo, Lobk National Park in Cameroon, and Dzanga-Ndoki National Park in Central African Republic.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [13, 25, people] in the following text because the character span 'populations ' does not align with token boundaries:
#
# "In addition, populations of critically endangered plant species such as Mukulungu are protected within the site's borders."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 9, landmark_name] in the following text because the character span 'park ' does not align with token boundaries:
#
# 'The park contains two active volcanoes (Tungurahua and Sangay), one extinct volcano El Altar (Kapak Urku).'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 4, number] in the following text because the character span '327 ' does not align with token boundaries:
#
# '327 lakes feed into a vast wetland system covering .'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 8, number] in the following text because the character span 'two ' does not align with token boundaries:
#
# 'The two villages and their monasteries are similar in many ways, and lie in plain view of each other on a dissected plateau formation, separated by a deep crack formed by a small river flowing into the Debed river.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 12, landmark_name] in the following text because the character span 'reserve ' does not align with token boundaries:
#
# 'The reserve is located in the Trans-Mexican Volcanic Belt pine-oak forests ecoregion on the border of Michoacn and State of Mexico, 100km (62 miles), northwest of Mexico City.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 9, number] in the following text because the character span 'Millions ' does not align with token boundaries:
#
# 'Millions of butterflies arrive in the reserve annually.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 12, animal] in the following text because the character span 'Butterflies ' does not align with token boundaries:
#
# 'Butterflies only inhabit a fraction of the 56,000 hectares of the reserve from OctoberMarch.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 8, condition] in the following text because the character span 'Created ' does not align with token boundaries:
#
# 'Created in 1985 by the Government of Quebec, Miguasha was designated a World Heritage Site in 1999 in recognition of its wealth of fossils, which display a crucial time during the evolution of life on Earth.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [21, 26, landmark_name] in the following text because the character span 'site ' does not align with token boundaries:
#
# 'Other names for this site are the Miguasha Fossil Site, the Bay of Escuminac Fossil Site, the Upper Devonian Escuminac Formation, and the Hugh-Miller Cliffs.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 3, landmark_name] in the following text because the character span 'It ' does not align with token boundaries:
#
# "It is also sometimes referred to on fossil specimens as 'Scaumenac Bay' or 'Scaumenac Bay P.Q.'"
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 3, landmark_name] in the following text because the character span 'It ' does not align with token boundaries:
#
# 'It has been a UNESCO World Heritage Site since 1979.The Medina contains some 700 monuments, including palaces, mosques, mausoleums, madrasas and fountains dating from the Almohad and the Hafsid periods.History.Founded in 698 around the original core of the Zitouna Mosque, the Medina of Tunis developed throughout the Middle Ages.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [30, 37, component] in the following text because the character span 'mosque ' does not align with token boundaries:
#
# 'The main axis was between the mosque and the centre of government to the west in the kasbah.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 11, condition] in the following text because the character span 'Expansions ' does not align with token boundaries:
#
# 'Expansions to the north and south divided the main Medina into two suburbs north (Bab Souika) and south (Bab El Jazira).'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [6, 10, number] in the following text because the character span 'one ' does not align with token boundaries:
#
# "It is one of Poland's World Heritage Sites (added in 1997)."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 19, landmark_name] in the following text because the character span 'Urnes Stave Church ' does not align with token boundaries:
#
# 'Urnes Stave Church () is a 12th-century stave church at Ornes, along the Lustrafjorden in the municipality of Luster in Vestland county, Norway.The church sits on the eastern side of the fjord, directly across the fjord from the village of Solvorn and about east of the village of Hafslo.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 3, landmark_name] in the following text because the character span 'It ' does not align with token boundaries:
#
# 'It was built at the end of the fifteenth century and is designated as a UNESCO World Heritage Site.UNESCO describes the tomb as a fine example of the monumental mud-building traditions of the West African Sahel.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 12, landmark_name] in the following text because the character span 'complex ' does not align with token boundaries:
#
# 'The complex includes the pyramidal tomb, two mosques, a cemetery and an assembly ground.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 8, occupation] in the following text because the character span 'Emperor ' does not align with token boundaries:
#
# 'Emperor Trajan named the city in commemoration of his mother Marcia, eldest sister Ulpia Marciana, and father Marcus Ulpius Traianus.Located in modern-day Algeria, about east of the city of Batna, the ruins are noteworthy for representing one of the best extant examples of the grid plan as used in Roman town planning.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [3, 17, type] in the following text because the character span ' copper statue' does not align with token boundaries:
#
# 'The copper statue, a gift from the people of France, was designed by French sculptor Frdric Auguste Bartholdi and its metal framework was built by Gustave Eiffel.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 11, landmark_name] in the following text because the character span 'statue ' does not align with token boundaries:
#
# 'The statue was dedicated on October 28, 1886.The statue is a figure of Libertas, the Roman Goddess of Liberty.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 9, type] in the following text because the character span 'site ' does not align with token boundaries:
#
# 'The site comprises seven clusters Phase I: Libo Karst, Shilin Karst, and Wulong Karst inscribed in 2007, and Phase II: Guilin Karst, Shibing Karst, Jinfoshan Karst, and Huanjiang Karst inscribed in 2014.'
#
#   warnings.warn(msg)
# Finished convertin NER data
# Start converting NER data...
# Finished convertin NER data
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 9, type] in the following text because the character span 'site ' does not align with token boundaries:
#
# 'The site includes Durham Castle, Durham Cathedral, Durham University, Palace Green and University College, Durham.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [20, 29, number] in the following text because the character span 'hundreds ' does not align with token boundaries:
#
# 'It is named for the hundreds of paintings of hands stenciled, in multiple collages, on the rock walls.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 8, type] in the following text because the character span 'art ' does not align with token boundaries:
#
# 'The art was created in several waves between 7,300 BC and 700 AD, during the Archaic period of pre-Columbian South America.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [49, 69, component] in the following text because the character span 'remains of bone pipe' does not align with token boundaries:
#
# 'The age of the paintings was calculated from the remains of bone pipes used for spraying the paint on the wall of the cave to create the artwork, radiocarbon dating of the artwork, and stratigraphic dating.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 9, type] in the following text because the character span 'park ' does not align with token boundaries:
#
# 'The park was named a World Heritage Site by UNESCO.History.Canaima National Park was established on 12 June 1962.As early as 1990, the countries that participate in the Amazonian Cooperation Treaty had recommended expanding the Canaima National Park southward to connect it with Monte Roraima National Park in Brazil, with coordinated management of tourism, research and conservation.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 14, type] in the following text because the character span 'cathedral ' does not align with token boundaries:
#
# 'The cathedral is the seat of the Bishop of Amiens.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 7, landmark_name] in the following text because the character span 'Amiens ' does not align with token boundaries:
#
# 'Amiens is a classic example of the High Gothic style of Gothic architecture.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [48, 56, date] in the following text because the character span ' in 1997' does not align with token boundaries:
#
# 'It was inscribed as a UNESCO World Heritage Site in 1997 and expanded in 2001.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [20, 36, component] in the following text because the character span 'rich decoration ' does not align with token boundaries:
#
# 'These tombs feature rich decoration of stone statues and carvings and tiles with dragon motifs, illustrating the development of the funerary architecture of the Qing dynasty.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [49, 52, number] in the following text because the character span '300' does not align with token boundaries:
#
# '<mapframe text="Map of Ilulissat Icefjord" width=300 height=300 zoom=7 latitude=69.15 longitude=-50.2>'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [48, 54, number] in the following text because the character span ' 2,500' does not align with token boundaries:
#
# 'A peak on the opposite side of the river is over 2,500 meters high.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [67, 89, date] in the following text because the character span ' between 1999 and 2004' does not align with token boundaries:
#
# "The park was inscribed on UNESCO's List of World Heritage in Danger between 1999 and 2004 because of insecurity and a lack of resources in the park."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [3, 35, landmark_name] in the following text because the character span ' Monastery of Saint John of Rila' does not align with token boundaries:
#
# 'The Monastery of Saint John of Rila, also known as Rila Monastery "Sveti Ivan Rilski" (), is the largest and most famous Eastern Orthodox monastery in Bulgaria.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [6, 15, condition] in the following text because the character span 'situated ' does not align with token boundaries:
#
# 'It is situated in the southwestern Rila Mountains, south of the capital Sofia in the deep valley of the Rilska River ("Rila River") at an elevation of above sea level, inside of Rila Monastery Nature Park.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 14, type] in the following text because the character span 'monastery ' does not align with token boundaries:
#
# "The monastery is named after its founder, the hermit Ivan of Rila (876  946 AD), and houses around 60 monks.Founded in the 10th century, the Rila Monastery is regarded as one of Bulgaria's most important cultural, historical and architectural monuments and is a key tourist attraction for both Bulgaria and Southern Europe."
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [4, 14, type] in the following text because the character span 'monastery ' does not align with token boundaries:
#
# 'The monastery is depicted on the reverse of the 1 lev banknote, issued in 1999.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 8, condition] in the following text because the character span 'Erected ' does not align with token boundaries:
#
# 'Erected in the 16th century in the late Brick Gothic style, it is one of the few remaining architectural monuments of the former PolishLithuanian Commonwealth in contemporary Belarus.History.Duke Juryj Ivanavi Illini () began construction of the castle near the village of Mir after the turn of the 16th century in the Belarusian Gothic style.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 5, number] in the following text because the character span 'Five ' does not align with token boundaries:
#
# 'Five towers surrounded the courtyard of the citadel, the walls of which formed a square of on each side.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [0, 8, landmark_name] in the following text because the character span 'Meteora ' does not align with token boundaries:
#
# 'Meteora is located near the town of Kalabaka at the northwestern edge of the Plain of Thessaly near the Pineios river and Pindus Mountains.'
#
#   warnings.warn(msg)
# d:\TUe\2AMM30 - Text Mining\Text-Mining\ner_model\scripts\convert.py:23: UserWarning: Skipping entity [3, 27, landmark_name] in the following text because the character span ' Villa Romana del Casale' does not align with token boundaries:
#
# 'The Villa Romana del Casale (Sicilian: "Villa Rumana d Casali") is a large and elaborate Roman villa or palace located about 3km from the town of Piazza Armerina, Sicily.'
#
#   warnings.warn(msg)

# %%
from spacy.cli.train import train

train("ner_model/configs/config.cfg", output_path=NER_OUTPUT, overrides={"paths.train": NER_TRAIN_CORP, "paths.dev": NER_DEV_CORP})
# Out:
# ℹ Saving to output directory: ner_model\training_1
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# c:\Users\20182640\.virtualenvs\Text-Mining-xR8YyNgY\lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.6.0) was trained with spaCy v3.6.0 and may not be 100% compatible with the current version (3.7.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer',
# 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS TAGGER  LOSS PARSER  LOSS NER  LEMMA_ACC  ENTS_F  ENTS_P  ENTS_R  SPEED   SCORE
# ---  ------  ------------  -----------  -----------  --------  ---------  ------  ------  ------  ------  ------
#   0       0          0.00         0.00         0.00     23.18       0.00    0.00    0.00    0.00  3191.80    0.00
#   0     100          0.00         0.00         0.00    595.55       0.00    0.00    0.00    0.00  5440.95    0.00
#   1     200          0.00         0.00         0.00    799.97       0.00    0.00    0.00    0.00  5732.81    0.00
#   2     300          0.00         0.00         0.00    631.50       0.00   26.80   54.17   17.81  5791.21    0.06
#   3     400          0.00         0.00         0.00    588.15       0.00   33.66   60.71   23.29  5875.18    0.08
#   4     500          0.00         0.00         0.00    617.02       0.00   28.04   44.12   20.55  6906.86    0.07
#   5     600          0.00         0.00         0.00    671.86       0.00   33.96   54.55   24.66  5513.66    0.08
#   6     700          0.00         0.00         0.00    668.33       0.00   37.04   57.14   27.40  5674.97    0.09
#   8     800          0.00         0.00         0.00    759.36       0.00   35.40   50.00   27.40  6472.96    0.08
#  10     900          0.00         0.00         0.00    903.82       0.00   42.02   54.35   34.25  7050.96    0.10
#  11    1000          0.00         0.00         0.00    919.57       0.00   41.67   53.19   34.25  6482.37    0.10
#  13    1100          0.00         0.00         0.00   1033.05       0.00   41.67   53.19   34.25  4982.70    0.10
# ✔ Saved pipeline to output directory
# ner_model\training_1\model-last

# %%
from spacy.cli.evaluate import evaluate

evaluate(os.path.join(NER_OUTPUT, "model-best"), NER_DEV_CORP, output=os.path.join(NER_OUTPUT, "metrics.json"))
# Out:
# {'token_acc': 1.0,
#  'token_p': 1.0,
#  'token_r': 1.0,
#  'token_f': 1.0,
#  'tag_acc': None,
#  'sents_p': None,
#  'sents_r': None,
#  'sents_f': None,
#  'dep_uas': None,
#  'dep_las': None,
#  'dep_las_per_type': None,
#  'pos_acc': None,
#  'morph_acc': None,
#  'morph_micro_p': None,
#  'morph_micro_r': None,
#  'morph_micro_f': None,
#  'morph_per_feat': None,
#  'lemma_acc': None,
#  'ents_p': 0.5434782608695652,
#  'ents_r': 0.3424657534246575,
#  'ents_f': 0.4201680672268907,
#  'ents_per_type': {'landmark_name': {'p': 0.6785714285714286,
#    'r': 0.76,
#    'f': 0.7169811320754718},
#   'date': {'p': 0.6, 'r': 0.3333333333333333, 'f': 0.42857142857142855},
#   'number': {'p': 0.3333333333333333,
#    'r': 0.3333333333333333,
#    'f': 0.3333333333333333},
#   'people': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#   'component': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#   'location': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#   'type': {'p': 0.25, 'r': 0.14285714285714285, 'f': 0.18181818181818182},
#   'animal': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#   'condition': {'p': 0.0, 'r': 0.0, 'f': 0.0}},
#  'speed': 4475.868481115961}

# %% [markdown]
# ### 2.2 Visualizing the results
# The model is now trained. This model can be loaded into spacy and an example text can be visualized with the NER.

# %%
options = {
    "colors": {"location": "lightyellow",
               "person_name": "lightgreen",
               "landmark_name": "lightred",
               "condition": "lightblue"}
}

# Now test teh newly created spacy model on a sample text and visualize it using spacy
nlp = spacy.load(os.path.join(NER_OUTPUT, "model-best"))

example_text = str([text[0] for i, text in enumerate(training_data[:20]) if text != ""])
doc = nlp(example_text)

displacy.render(doc, style="ent", jupyter=True, options=options)

# Show the tokens, their labels and their entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">['Engelsberg Ironworks () is an ironworks in &quot;ngelsberg&quot;, a village in Fagersta Municipality in Vstmanland, Sweden.', &quot;It was built in 1681 by Per Larsson Gyllenhk (1645-1706) and developed into one of the world's most modern ironworks in the period 17001800.&quot;, 'It is listed as a UNESCO World Heritage Site since 1993.Name.Engelsberg Ironworks is named after Englika.', 'Englika, who was born in Germany, began producing iron in Engelsberg in the 14th century.History.The history of iron production in the region dates back to at least 13th century.', 'The local peasants both mined the ore and produced the iron using primitive furnaces.', 'The
# <mark class="entity" style="background: lightred; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emas National Park
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">landmark_name</span>
# </mark>
#  (, literally meaning &quot;Rhea National Park&quot;) is a national park and a UNESCO World Heritage Site in the states of Gois and Mato Grosso do Sul in Brazil.Description.The National Park is located between the states of Gois and Mato Grosso do Sul in the Center-West Region of Brazil, between 1750\'1815\'S and 5239\'5310\'W.', 'It covers of cerrado savannah.', 'The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     park
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">type</span>
# </mark>
#  is in the Pantanal Biosphere Reserve, which also includes the Pantanal, Chapada dos Guimares and Serra da Bodoquena national parks, and the Serra de Santa Brbara, Nascentes do Rio Taquari and Pantanal de Rio Negro state parks.', 'Ellora Caves are a multi-religious rock-cut cave complex with inscriptions dating from the period 6th century CE onwards, located in the Aurangabad District of Maharashtra, India.', 'There are over 100 caves at the site, all excavated from the basalt cliffs in the Charanandri Hills, 34 of which are open to public.', 'These consist of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">number</span>
# </mark>
#  Hindu (caves 1329), 12 Buddhist (caves 112) and 5 Jain (caves 3034) caves.', 'Each group represents deities and mythologies prevalent in the 1st millennium CE, as well as monasteries of each respective religion.', 'They were built close to one another and illustrate the religious harmony that existed in ancient India.', 'Because of their exceptional architecture of ancient India, the Ellora Caves were inscribed on the UNESCO World Heritage List in 1983.', 'The Elephanta Caves are a collection of cave temples predominantly dedicated to the Hindu god Shiva, which have been designated a UNESCO World Heritage Site.', 'They are on Elephanta Island, or &quot;Gharapuri&quot; (literally meaning &quot;the city of caves&quot;), in Mumbai Harbour, east of Mumbai in the Indian state of Mahrshtra.', 'The island, about west of the Jawaharlal Nehru Port, consists of five Hindu caves, a few Buddhist stupa mounds that date back to the 2nd century BCE, and two Buddhist caves with water tanks.', 'East Rennell is the southern portion of Rennell Island in the Solomon Islands which is designated a UNESCO World Heritage Site.', &quot;Rennell is the largest raised coral atoll in the world and the area in East Rennell surrounding Lake Tegano contains many endemic species.In 2013, the World Heritage Committee added East Rennell to the List of World Heritage in Danger because of the threat of logging activities to the site's outstanding universal value.Site.Rennell is situated in the Western Pacific and is the southernmost of the Solomon Islands, being some .&quot;, 'It is the largest uplifted coral atoll in the world, occupying .']</div></span>
# Emas National Park landmark_name
# park type
# 17 number

# %% [markdown]
# ### 2.3 Training the Spacy Custom REL component

# %%
import subprocess
if spacy.prefer_gpu():
    output = subprocess.run(f"spacy project run all_{COMPONENT}_gpu", cwd="rel_model", capture_output=True)
else:
    output = subprocess.run(f"spacy project run all_{COMPONENT}", cwd="rel_model", capture_output=True)

print(output.stdout.decode("utf-8"))

# %% [markdown]
# ## 2.4 Visualizing the results

# %%
# make the factory work
from rel_model.scripts.rel_pipe import make_relation_extractor

# make the config work
from rel_model.scripts.rel_model import create_relation_model, create_classification_layer, create_instances, create_tensors

# Now test teh newly created spacy model on a sample text and visualize it using spacy
nlp2 = spacy.load(os.path.join(REL_OUTPUT, "model-best"))

doc = nlp2(doc.text) # doc is the output from the NER model (nlp)

displacy.render(doc, style="ent", jupyter=True, options=options)

# Show the tokens, their labels and their entities
for rel in doc._.rel:
    print(rel)
# Out:
# ℹ Could not determine any instances in doc - returning doc as is.
# c:\Users\20182640\.virtualenvs\Text-Mining-xR8YyNgY\lib\site-packages\spacy\displacy\__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">['Engelsberg Ironworks () is an ironworks in &quot;ngelsberg&quot;, a village in Fagersta Municipality in Vstmanland, Sweden.', &quot;It was built in 1681 by Per Larsson Gyllenhk (1645-1706) and developed into one of the world's most modern ironworks in the period 17001800.&quot;, 'It is listed as a UNESCO World Heritage Site since 1993.Name.Engelsberg Ironworks is named after Englika.', 'Englika, who was born in Germany, began producing iron in Engelsberg in the 14th century.History.The history of iron production in the region dates back to at least 13th century.', 'The local peasants both mined the ore and produced the iron using primitive furnaces.', 'The Emas National Park (, literally meaning &quot;Rhea National Park&quot;) is a national park and a UNESCO World Heritage Site in the states of Gois and Mato Grosso do Sul in Brazil.Description.The National Park is located between the states of Gois and Mato Grosso do Sul in the Center-West Region of Brazil, between 1750\'1815\'S and 5239\'5310\'W.', 'It covers of cerrado savannah.', 'The park is in the Pantanal Biosphere Reserve, which also includes the Pantanal, Chapada dos Guimares and Serra da Bodoquena national parks, and the Serra de Santa Brbara, Nascentes do Rio Taquari and Pantanal de Rio Negro state parks.', 'Ellora Caves are a multi-religious rock-cut cave complex with inscriptions dating from the period 6th century CE onwards, located in the Aurangabad District of Maharashtra, India.', 'There are over 100 caves at the site, all excavated from the basalt cliffs in the Charanandri Hills, 34 of which are open to public.', 'These consist of 17 Hindu (caves 1329), 12 Buddhist (caves 112) and 5 Jain (caves 3034) caves.', 'Each group represents deities and mythologies prevalent in the 1st millennium CE, as well as monasteries of each respective religion.', 'They were built close to one another and illustrate the religious harmony that existed in ancient India.', 'Because of their exceptional architecture of ancient India, the Ellora Caves were inscribed on the UNESCO World Heritage List in 1983.', 'The Elephanta Caves are a collection of cave temples predominantly dedicated to the Hindu god Shiva, which have been designated a UNESCO World Heritage Site.', 'They are on Elephanta Island, or &quot;Gharapuri&quot; (literally meaning &quot;the city of caves&quot;), in Mumbai Harbour, east of Mumbai in the Indian state of Mahrshtra.', 'The island, about west of the Jawaharlal Nehru Port, consists of five Hindu caves, a few Buddhist stupa mounds that date back to the 2nd century BCE, and two Buddhist caves with water tanks.', 'East Rennell is the southern portion of Rennell Island in the Solomon Islands which is designated a UNESCO World Heritage Site.', &quot;Rennell is the largest raised coral atoll in the world and the area in East Rennell surrounding Lake Tegano contains many endemic species.In 2013, the World Heritage Committee added East Rennell to the List of World Heritage in Danger because of the threat of logging activities to the site's outstanding universal value.Site.Rennell is situated in the Western Pacific and is the southernmost of the Solomon Islands, being some .&quot;, 'It is the largest uplifted coral atoll in the world, occupying .']</div></span>
